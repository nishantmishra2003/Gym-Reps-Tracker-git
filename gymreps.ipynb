# %%
#setting up the dependencies
import cv2 
#mediapipe is a framework which is used for ml that allows us to build a pipeline for cv,text,audio etc
import mediapipe as mp
import numpy as np
#it provides the drawing utilities and is used for visualizing the keypoints/landmarks on the images or frames
mp_drawing = mp.solutions.drawing_utils
#this is a pose estimation module used to determine the different human poses
mp_pose = mp.solutions.pose

# %%
#setting up the web camera and settin the keypoints and the pose
cap = cv2.VideoCapture(0)
#this block of code is used for the pose detction and finding and marking the keypoints:
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret,frame = cap.read()
        #recolor image for mediapipe
        image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        results = pose.process(image)
        
        #recolor the image back to bgr because the cv dosent accept rgb format 
        image.flags.writeable = True
        image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
        #render detctions 
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        if ret:
            cv2.imshow('video',image)
            if cv2.waitKey(100) == ord('q'):
                break
        else:
            break
               
cap.release()
cv2.destroyAllWindows()

# %%
#extraction of the keypoints 
cap = cv2.VideoCapture(0)
#this block of code is used for the pose detction and finding and marking the keypoints:
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret,frame = cap.read()
        #recolor image for mediapipe
        image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        results = pose.process(image)
        
        #recolor the image back to bgr because the cv dosent accept rgb format 
        image.flags.writeable = True
        image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)

        #extract the landmarks:
        try:
            landmarks = results.pose_landmarks.landmark
            print(landmarks)
        except:
            pass
        #render detctions 
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        if ret:
            cv2.imshow('video',image)
            if cv2.waitKey(100) == ord('q'):
                break
        else:
            break
               
cap.release()
cv2.destroyAllWindows()
# Out:
# [x: 0.640281498
# y: 0.749957085
# z: -2.32203913
# visibility: 0.987973094
# , x: 0.67474544
# y: 0.632934
# z: -2.28145623
# visibility: 0.977301657
# , x: 0.69851023
# y: 0.626233459
# z: -2.28195596
# visibility: 0.976281047
# , x: 0.721559703
# y: 0.619509101
# z: -2.28241372
# visibility: 0.96791178
# , x: 0.584957778
# y: 0.640245318
# z: -2.28966951
# visibility: 0.984599411
# , x: 0.548334539
# y: 0.638691485
# z: -2.28994918
# visibility: 0.986916423
# , x: 0.516510904
# y: 0.637216032
# z: -2.29069519
# visibility: 0.987010479
# , x: 0.749119937
# y: 0.612504423
# z: -1.67812252
# visibility: 0.972818613
# , x: 0.469022036
# y: 0.643465757
# z: -1.69186568
# visibility: 0.993400097
# , x: 0.671320558
# y: 0.82883966
# z: -2.05637026
# visibility: 0.979645252
# , x: 0.582824
# y: 0.830732703
# z: -2.06243825
# visibility: 0.989645
# , x: 0.923493266
# y: 0.903570056
# z: -0.998955131
# visibility: 0.898663342
# , x: 0.313168377
# y: 0.957397342
# z: -1.05497074
# ...

# %%
print(landmarks)
# Out:
# [x: 0.613697886
# y: 0.72916013
# z: -2.48497844
# visibility: 0.991315663
# , x: 0.657803714
# y: 0.606011271
# z: -2.43965292
# visibility: 0.984502375
# , x: 0.684712946
# y: 0.599447191
# z: -2.44029641
# visibility: 0.984227896
# , x: 0.706585109
# y: 0.59395659
# z: -2.44092607
# visibility: 0.978141785
# , x: 0.553660452
# y: 0.618757784
# z: -2.43593621
# visibility: 0.989229739
# , x: 0.5211128
# y: 0.619460464
# z: -2.43608427
# visibility: 0.990682662
# , x: 0.496732771
# y: 0.619841397
# z: -2.43665266
# visibility: 0.990483463
# , x: 0.74230969
# y: 0.589326084
# z: -1.77092457
# visibility: 0.982301652
# , x: 0.458777338
# y: 0.621714294
# z: -1.72845495
# visibility: 0.995677948
# , x: 0.666406214
# y: 0.808961034
# z: -2.19375443
# visibility: 0.985830069
# , x: 0.564928889
# y: 0.826183
# z: -2.18276644
# visibility: 0.99276948
# , x: 0.914087
# y: 0.901403189
# z: -1.08122134
# visibility: 0.930499375
# , x: 0.312294811
# y: 0.96129626
# z: -0.909527302
# ...

# %%
#marking the landmarks that we need to exatract and use to calculate 
landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value]
# Out:
# x: 0.914087
# y: 0.901403189
# z: -1.08122134
# visibility: 0.930499375

# %%
landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value]
# Out:
# x: 1.16609
# y: 1.31378162
# z: -1.18362176
# visibility: 0.121537186

# %%
landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value]
# Out:
# x: 1.11201
# y: 1.61109781
# z: -1.97393739
# visibility: 0.0195815824

# %%
#now we are gonna calculate the angles
def calculate(a,b,c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    radians = np.arctan2(c[1]-b[1],c[0]-b[0])-np.arctan2(a[1]-b[1],a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    if angle>180.0:
        angle = 360-angle
    return angle

# %%
shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

# %%
shoulder, elbow, wrist
# Out:
# ([0.9140869975090027, 0.9014031887054443],
#  [1.1660900115966797, 1.3137816190719604],
#  [1.1120100021362305, 1.611097812652588])

# %%
calculate (shoulder, elbow, wrist)
# Out:
# 138.26199674015922

# %%
tuple(np.multiply(elbow, [640, 480]).astype(int))
# Out:
# (746, 630)

# %%
cap = cv2.VideoCapture(0)
## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            
            # Get coordinates
            shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            
            # Calculate angle
            angle = calculate_angle(shoulder, elbow, wrist)
            
            # Visualize angle
            cv2.putText(image, str(angle), 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA
                                )
                       
        except:
            pass
        
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
#now we are setting up the curl counter to count the number of reps that are done 
cap = cv2.VideoCapture(0)

# Curl counter variables
counter = 0 
stage = None

## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            
            # Get coordinates
            shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            
            # Calculate angle
            angle = calculate_angle(shoulder, elbow, wrist)
            
            # Visualize angle
            cv2.putText(image, str(angle), 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA
                                )
            
            # Curl counter logic
            if angle > 160:
                stage = "down"
            if angle < 30 and stage =='down':
                stage="up"
                counter +=1
                print(counter)
                       
        except:
            pass
        
        # Render curl counter
        # Setup status box
        cv2.rectangle(image, (0,0), (225,73), (245,117,16), -1)
        
        # Rep data
        cv2.putText(image, 'REPS', (15,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, str(counter), 
                    (10,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        # Stage data
        cv2.putText(image, 'STAGE', (65,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage, 
                    (60,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
